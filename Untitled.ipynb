# %%
train = pd.read_csv('data/train.csv')
test = pd.read_csv('data/test.csv')
weather = pd.read_csv('data/weather.csv')

# %%
test['units']=np.nan

# %%
len(test), len(train), len(weather)
# Out:
# (526917, 4617600, 20517)

# %%
train.isna().sum()
# Out:
# date         0
# store_nbr    0
# item_nbr     0
# units        0
# dtype: int64

# %%
test.isna().sum()
# Out:
# date              0
# store_nbr         0
# item_nbr          0
# units        526917
# dtype: int64

# %%
merged_train = pd.concat([train, test])

# %%
len(merged_train)
# Out:
# 5144517

# %%
merged_train = merged_train.sort_values(by=['date','store_nbr','item_nbr'])

# %%
merged_train.isna().sum()
# Out:
# date              0
# store_nbr         0
# item_nbr          0
# units        526917
# dtype: int64

# %%
weather.isna().sum()
# Out:
# station_nbr    0
# date           0
# tmax           0
# tmin           0
# tavg           0
# depart         0
# dewpoint       0
# wetbulb        0
# heat           0
# cool           0
# sunrise        0
# sunset         0
# codesum        0
# snowfall       0
# preciptotal    0
# stnpressure    0
# sealevel       0
# resultspeed    0
# resultdir      0
# avgspeed       0
# dtype: int64

# %%
weather2 = weather.replace('-', np.nan) 
weather2 = weather2.replace('T', 0)

# %%
weather2
# Out:
#        station_nbr        date tmax tmin tavg depart dewpoint wetbulb heat  \
# 0                1  2012-01-01   52   31   42      M       36      40   23
# 1                2  2012-01-01   48   33   41     16       37      39   24
# 2                3  2012-01-01   55   34   45      9       24      36   20
# 3                4  2012-01-01   63   47   55      4       28      43   10
# 4                6  2012-01-01   63   34   49      0       31      43   16
# 5                7  2012-01-01   50   33   42      M       26      35   23
# 6                8  2012-01-01   66   45    M      M       34      46    M
# 7                9  2012-01-01   34   19   27      M       17      23   38
# 8               10  2012-01-01   73   53   63      M       55      58    2
# 9               11  2012-01-01   72   48   60      7       54      56    5
# 10              12  2012-01-01   72   48   60      M       54      57    5
# ...
